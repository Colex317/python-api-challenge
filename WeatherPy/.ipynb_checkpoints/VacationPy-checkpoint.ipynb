# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv('../output_data/cities.csv')

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0      hermanus -34.4187   19.2345     21.00        88           4
# 1        1   olonkinbyen  70.9221   -8.7187     -5.70        76         100
# 2        2  port lincoln -34.7333  135.8667     17.25        62          99
# 3        3        uturoa -16.7333 -151.4333     27.43        80         100
# 4        4    whitehorse  60.7161 -135.0538    -25.57        64          75
#
#    Wind Speed Country        Date
# 0        0.69      ZA  1707080460
# 1       11.11      SJ  1707079882
# 2        7.46      AU  1707080460
# 3        6.89      PF  1707080461
# 4        2.06      CA  1707080461

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    color = "City"
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit the criteria and drop any results with null values
    # A max temperature lower than 27 degrees but higher than 21
    # Wind speed less than 4.5 m/s
    # Zero cloudiness

city_data_df = city_data_df[
    (city_data_df["Max Temp"] >= 21) & (city_data_df["Max Temp"] <= 27) &
    (city_data_df["Wind Speed"] <= 4.5) & (city_data_df["Cloudiness"] == 0)
].copy()

# Drop any rows with null values
city_data_df.dropna(axis='rows', inplace=True)

# Display sample data
city_data_df
# Out:
#      City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 56        56                  salaya  22.3167   69.6000     22.14        94
# 74        74          port elizabeth -33.9180   25.5701     21.72        95
# 119      119            paradip garh  20.3167   86.6167     22.29        85
# 149      149                 mangrol  21.1167   70.1167     22.18        86
# 158      158  san ignacio rio muerto  27.4167 -110.2333     26.54        17
# 172      172           narasannapeta  18.4167   84.0500     21.10        91
# 189      189             nova sintra  14.8667  -24.7167     21.27        71
# 227      227                    puri  19.8000   85.8500     22.29        83
# 349      349                key west  24.5557  -81.7826     25.00        80
# 367      367                  ongole  15.5000   80.0500     23.13        82
# 491      491                  bhalki  18.0333   77.2167     22.76        49
# 545      545            saint-pierre -21.3393   55.4781     21.82        78
#
#      Cloudiness  Wind Speed Country        Date
# 56            0        3.13      IN  1707080478
# 74            0        1.03      ZA  1707080487
# 119           0        2.97      IN  1707080504
# 149           0        4.05      IN  1707080512
# 158           0        3.95      MX  1707080515
# 172           0        1.47      IN  1707080518
# 189           0        4.04      CV  1707080523
# 227           0        3.43      IN  1707080537
# 349           0        3.58      US  1707080568
# 367           0        2.39      IN  1707080551
# 491           0        2.45      IN  1707080628
# 545           0        2.06      RE  1707080640

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
#                        City Country      Lat       Lng  Humidity Hotel Name
# 56                   salaya      IN  22.3167   69.6000        94
# 74           port elizabeth      ZA -33.9180   25.5701        95
# 119            paradip garh      IN  20.3167   86.6167        85
# 149                 mangrol      IN  21.1167   70.1167        86
# 158  san ignacio rio muerto      MX  27.4167 -110.2333        17
# 172           narasannapeta      IN  18.4167   84.0500        91
# 189             nova sintra      CV  14.8667  -24.7167        71
# 227                    puri      IN  19.8000   85.8500        83
# 349                key west      US  24.5557  -81.7826        80
# 367                  ongole      IN  15.5000   80.0500        82
# 491                  bhalki      IN  18.0333   77.2167        49
# 545            saint-pierre      RE -21.3393   55.4781        78

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    'categories': 'accommodation.hotel',
    'apiKey': geoapify_key,
    'limit': 20
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lon = row['Lng']
    lat = row['Lat']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f'circle:{lon},{lat},{radius}'
    params["bias"] = f'proximity:{lon},{lat}'
   
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make an API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# salaya - nearest hotel: No hotel found
# port elizabeth - nearest hotel: Waterford Hotel
# paradip garh - nearest hotel: Hotel Sea Pearl
# mangrol - nearest hotel: No hotel found
# san ignacio rio muerto - nearest hotel: No hotel found
# narasannapeta - nearest hotel: No hotel found
# nova sintra - nearest hotel: Residência Ka Dencho
# puri - nearest hotel: Divine Beach Homestay
# key west - nearest hotel: Harborside Hotel & Marina
# ongole - nearest hotel: KOLAS Hotel
# bhalki - nearest hotel: Bhagyavanti Bkit Hotel
# saint-pierre - nearest hotel: Tropic Hotel
#                        City Country      Lat       Lng  Humidity  \
# 56                   salaya      IN  22.3167   69.6000        94
# 74           port elizabeth      ZA -33.9180   25.5701        95
# 119            paradip garh      IN  20.3167   86.6167        85
# 149                 mangrol      IN  21.1167   70.1167        86
# 158  san ignacio rio muerto      MX  27.4167 -110.2333        17
# 172           narasannapeta      IN  18.4167   84.0500        91
# 189             nova sintra      CV  14.8667  -24.7167        71
# 227                    puri      IN  19.8000   85.8500        83
# 349                key west      US  24.5557  -81.7826        80
# 367                  ongole      IN  15.5000   80.0500        82
# 491                  bhalki      IN  18.0333   77.2167        49
# 545            saint-pierre      RE -21.3393   55.4781        78
#
#                     Hotel Name
# 56              No hotel found
# 74             Waterford Hotel
# 119            Hotel Sea Pearl
# 149             No hotel found
# 158             No hotel found
# 172             No hotel found
# 189       Residência Ka Dencho
# 227      Divine Beach Homestay
# 349  Harborside Hotel & Marina
# 367                KOLAS Hotel
# 491     Bhagyavanti Bkit Hotel
# 545               Tropic Hotel

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    color = "City"
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City)
